# %%
import os
import re
import subprocess

# 指定專案目錄（預設當前目錄）
project_directory = '.'

# 用來識別 import 語句的正則表達式模式
import_pattern = re.compile(r'^(?:from\s+(\S+)\s+import|import\s+(\S+))')

# 用於存儲獨特的套件名稱
packages = set()

# 掃描專案目錄中的所有 .py 檔案
for root, dirs, files in os.walk(project_directory):
    for file in files:
        if file.endswith('.py'):
            print(f"正在掃描 {file} 檔案")
            file_path = os.path.join(root, file)
            with open(file_path, 'r', encoding='utf-8') as f:
                for line in f:
                    # 匹配 import 語句
                    match = import_pattern.match(line.strip())
                    if match:
                        package = match.group(1) or match.group(2)
                        if package and not package.startswith('.'):  # 忽略相對匯入
                            packages.add(package.split('.')[0])  # 只保留頂層的套件名稱

# 使用 pip freeze 來捕捉套件的版本並生成 requirements.txt
with open('requirements.txt', 'w') as req_file:
    for package in packages:
        try:
            # 使用 pip show 來獲取套件版本
            result = subprocess.run(['pip', 'show', package], stdout=subprocess.PIPE, text=True)
            for line in result.stdout.splitlines():
                if line.startswith('Version:'):
                    version = line.split()[-1]
                    req_file.write(f"{package}=={version}\n")
                    break
        except Exception as e:
            print(f"處理套件 {package} 時出錯: {e}")

print("requirements.txt 已成功生成。")
# Out:
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_EB.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_AL.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_FB.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_PB.py 檔案
# 正在掃描 generate_requirements.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_CAL.py 檔案
# 正在掃描 Step4_合併所有原始解析度切割結果影像＿輸出.py 檔案
# 正在掃描 Step1_讀取DLG_tif檔案_輸出成2D投影圖.py 檔案
# 正在掃描 detect_custom_color.py 檔案
# 正在掃描 GUI.py 檔案
# 正在掃描 Step2_2024_最終使用者網頁應用程式_YOLOv7_inference.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_MB.py 檔案
# 正在掃描 datasets.py 檔案
# 正在掃描 add_nms.py 檔案
# 正在掃描 plots.py 檔案
# 正在掃描 torch_utils.py 檔案
# 正在掃描 google_utils.py 檔案
# 正在掃描 autoanchor.py 檔案
# 正在掃描 __init__.py 檔案
# 正在掃描 activations.py 檔案
# 正在掃描 general.py 檔案
# 正在掃描 loss.py 檔案
# 正在掃描 loss_old.py 檔案
# 正在掃描 metrics.py 檔案
# 正在掃描 plots-checkpoint.py 檔案
# 正在掃描 loss_old-checkpoint.py 檔案
# 正在掃描 google_utils-checkpoint.py 檔案
# 正在掃描 resume.py 檔案
# 正在掃描 __init__.py 檔案
# 正在掃描 wandb_utils.py 檔案
# 正在掃描 log_dataset.py 檔案
# 正在掃描 __init__.py 檔案
# 正在掃描 Step1_讀取DLG_tif檔案_輸出成2D投影圖-checkpoint.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_PB-checkpoint.py 檔案
# 正在掃描 GUI-checkpoint.py 檔案
# 正在掃描 detect_custom_color-checkpoint.py 檔案
# 正在掃描 Step4_合併所有原始解析度切割結果影像＿輸出-checkpoint.py 檔案
# 正在掃描 generate_requirements-checkpoint.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_AL-checkpoint.py 檔案
# 正在掃描 Step2_2024_最終使用者網頁應用程式_YOLOv7_inference-checkpoint.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_MB-checkpoint.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_FB-checkpoint.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_EB-checkpoint.py 檔案
# 正在掃描 Step3_YOLO結果預處理給3D_UNet切割_輸出放回原始影像_CAL-checkpoint.py 檔案
# 正在掃描 common.py 檔案
# 正在掃描 __init__.py 檔案
# 正在掃描 yolo.py 檔案
# 正在掃描 experimental.py 檔案
# WARNING: Package(s) not found: typing
# WARNING: Package(s) not found: cv2
# WARNING: Package(s) not found: wandb
# WARNING: Package(s) not found: re
# WARNING: Package(s) not found: pickle
# WARNING: Package(s) not found: sys
# WARNING: Package(s) not found: glob
# WARNING: Package(s) not found: itertools
# WARNING: Package(s) not found: base64
# WARNING: Package(s) not found: pafy
# WARNING: Package(s) not found: gc
# WARNING: Package(s) not found: pathlib
# WARNING: Package(s) not found: socket
# WARNING: Package(s) not found: utils
# WARNING: Package(s) not found: time
# WARNING: Package(s) not found: os
# WARNING: Package(s) not found: wandb_utils
# WARNING: Package(s) not found: platform
# WARNING: Package(s) not found: PIL
# WARNING: Package(s) not found: yaml
# WARNING: Package(s) not found: contextlib
# WARNING: Package(s) not found: skimage
# WARNING: Package(s) not found: argparse
# WARNING: Package(s) not found: onnx_graphsurgeon
# WARNING: Package(s) not found: shutil
# WARNING: Package(s) not found: threading
# WARNING: Package(s) not found: math
# WARNING: Package(s) not found: pkg_resources
# WARNING: Package(s) not found: models
# WARNING: Package(s) not found: logging
# WARNING: Package(s) not found: subprocess
# WARNING: Package(s) not found: random
# WARNING: Package(s) not found: multiprocessing
# WARNING: Package(s) not found: copy
# requirements.txt 已成功生成。
# WARNING: Package(s) not found: json
