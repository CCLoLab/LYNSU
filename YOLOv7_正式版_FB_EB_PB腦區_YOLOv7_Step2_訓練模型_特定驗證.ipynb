# %%
#Step1 開始訓練偵測 FB_EB_PB腦區，輸出訓練資料在: 
# 使用1 GPU
# 為了解決訓練時的問題:RuntimeError:indices should be either on cpu or on the same device as the indexed tensor(cpu)
# !python train.py --weights weights/yolov7x_training.pt --cfg cfg/training/yolov7x_FB_EB_PB.yaml --data data/voc_FB_EB_PB_1type.yaml --epochs 10 --batch-size 32 --img-size 640 --project FB_EB_PB_trained/train

# %% [markdown]
# # 已經複製過無須再複製
# # Step2 完成訓練後，推理先前人工確認的圖片，測試是否準確度夠高
# # 先將需要推理的圖片複製到 人工驗證 資料夾
# import os
# import numpy as np
# import matplotlib.pyplot as plt
# import cv2
# import shutil
# import time
# import random
# # 600張隨機人工驗證完成的圖片路徑: /raid/LoLab/kaiyi_hsu/DASH_Website/assets/True
# # 讀取 路徑: /raid/LoLab/kaiyi_hsu/DASH_Website/assets/True/ 內的檔案名稱
# human_validated_path = '/raid/LoLab/kaiyi_hsu/DASH_Website/assets/True/'
# # 讀取 路徑: /raid/LoLab/kaiyi_hsu/DASH_Website/assets/True/ 內的檔案名稱
# human_validated_files = os.listdir(human_validated_path)
# print('人工驗證圖片 總共數量: ',len(human_validated_files))
# # 讀取圖片的路徑
# XY_view_path = '/raid/LoLab/kaiyi_hsu/YOLO/果蠅腦XY圖_人工標記Label/XY_View/'
# # 複製 XY_view_path 路徑中 600張human_validated_files 到 /raid/LoLab/kaiyi_hsu/2023_YOLOv7_FCN/Neuron_image_and_label/人工驗證/ 資料夾
# output_txt_path = '/raid/LoLab/kaiyi_hsu/2023_YOLOv7_FCN/Neuron_image_and_label/人工驗證/'
# for i in range(len(human_validated_files)):
#     shutil.copy(XY_view_path+human_validated_files[i], output_txt_path+human_validated_files[i])

# %%
# Step3 開始推理 al_trained 資料夾內 exp是Zsum & Zmax都有訓練的模型
# GT顏色 = #FFC000 = (0, 192, 255) 問GPT: #FFC000 對應BGR表示法[detect.py 預設是GT的顏色]
# MB顏色 = #00B0F0 = (240, 176, 0) 問GPT: #00B0F0 對應BGR表示法
# AL顏色 = #FF0000 = (0, 0, 255)   問GPT: #FF0000 對應BGR表示法
# !python detect.py --conf-thres 0.5 --color 0 0 255 --weights ./FB_EB_PB_trained/train/exp/weights/best.pt --source Neuron_image_and_label/人工驗證 --img-size 640 --save-txt --project FB_EB_PB_inference/Test
# Out:
# opt==== Namespace(agnostic_nms=False, augment=False, classes=None, color=[0, 0, 255], conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='FB_EB_PB_inference/Test', save_conf=False, save_txt=True, source='Neuron_image_and_label/人工驗證', update=False, view_img=False, weights=['./FB_EB_PB_trained/train/exp/weights/best.pt'])
# custom_color:  [0, 0, 255]
# YOLOR 🚀 2022-11-10 torch 2.0.0+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40536.1875MB)
#
# Fusing layers...
# IDetect.fuse
# /root/.local/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 362 layers, 70782444 parameters, 0 gradients, 188.0 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 1 CC, Done. (9.2ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/5HT1A-F-300020.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/5HT1A-F-700007.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/5HT1A-F-800031.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000066.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000076.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000106.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000163.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000198.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000334.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000380.png
# 1 CC, Done. (7.5ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000386.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000389.png
# 1 CC, Done. (7.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000406.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000451.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-000499.png
# 1 CC, Done. (7.7ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-100023.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-100032.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-100178.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-100209.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-100257.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-100260.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-100313.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-100349.png
# 1 CC, Done. (6.3ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Cha-F-
2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-000170.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-100080.png
# 1 CC, Done. (7.6ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-200005.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-200044.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-200082.png
# 1 CC, Done. (7.7ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-300036.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-300098.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-300123.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-400018.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-400033.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-400121.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-500069.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-600046.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-600047.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-600067.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-600083.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/Trh-M-700032.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000053.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000059.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000140.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000179.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000245.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000320.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000349.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000352.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000358.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000528.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000604.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000623.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000651.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000672.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-000673.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-100073.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-100172.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-100187.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-100201.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-100243.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-100252.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-100320.png
# 1 CC, Done. (7.5ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-100334.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-100339.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200101.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200125.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200163.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200235.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200281.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200336.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200374.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200423.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200435.png
# 1 CC, Done. (6.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200454.png
# 1 CC, Done. (7.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200477.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200557.png
# 1 CC, Done. (10.2ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-200589.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-300112.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-300159.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-300231.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/VGlut-F-300393.png
# ...
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-400072.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-400101.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-400138.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-400216.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-400262.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-400332.png
# 1 CC, Done. (7.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-400335.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500053.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500066.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500079.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500107.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500170.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500191.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500195.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500264.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500285.png
# 1 CC, Done. (7.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500292.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500372.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500418.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500436.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500487.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500490.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500574.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-500578.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-600058.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-600069.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-600090.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-600093.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-600115.png
# 1 CC, Done. (7.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-600125.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-600228.png
# 1 CC, Done. (7.5ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-600294.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-700064.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-700076.png
# 1 CC, Done. (7.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-700089.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-700154.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-700173.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-700184.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-700212.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-700290.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-800007.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-800065.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-800098.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-F-900033.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-000003.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-000261.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-000275.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-000281.png
# 1 CC, Done. (7.6ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100013.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100018.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100022.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100181.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100188.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100229.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100239.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100253.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100270.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100275.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100332.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-100395.png
# 1 CC, Done. (6.2ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200017.png
# 1 CC, Done. (7.4ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200038.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200101.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200158.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200210.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200219.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200236.png
# 1 CC, Done. (7.6ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200285.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200339.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200408.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-200449.png
# 1 CC, Done. (9.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300005.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300015.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300040.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300108.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300214.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300215.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300236.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300244.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300265.png
# 1 CC, Done. (7.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300298.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300309.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300336.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-300418.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-400008.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-400047.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-400091.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-400109.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-400187.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-400205.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-400243.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-400271.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-400310.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500008.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500050.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500070.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500127.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500128.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500170.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500194.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500272.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500302.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500342.png
# 1 CC, Done. (7.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500358.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-500388.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-600046.png
# 1 CC, Done. (7.5ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-600051.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-600091.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-600108.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-600131.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-600166.png
# 1 CC, Done. (7.6ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-600175.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-600186.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-700065.png
# 1 CC, Done. (7.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-800003.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-800137.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-900087.png
# 1 CC, Done. (7.7ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-900089.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/fru-M-900102.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/npf-F-100009.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/npf-F-200034.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/npf-F-300007.png
# 1 CC, Done. (7.5ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/npf-M-100024.png
# 1 CC, Done. (7.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/npf-M-200025.png
# 1 CC, Done. (7.6ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: FB_EB_PB_inference/Test/exp/npf-M-300021.png
# Done. (43.961s)

# %%
# Step4 檢查沒有預測出 CC的大腦編號(人工檢視)
import os
# 等待推理的資料夾: Neuron_image_and_label/人工驗證/
input_dir = 'Neuron_image_and_label/人工驗證/'
# YOLO推理輸出的資料夾: al_inference/Test/exp/
output_dir = 'FB_EB_PB_inference/Test/exp/'
# 列出所有等待推理的圖片
input_files = os.listdir(input_dir)
print('等待推理的圖片數量: ',len(input_files))
# 列出所有YOLO推理輸出的圖片，只列出副檔名為png的圖片
output_files = [f for f in os.listdir(output_dir) if f.endswith('.png')]
print('完成推理的圖片數量: ',len(output_files))
# 比對input_files與output_files，找出沒有推理輸出的圖片(紀錄在沒有推理輸出的圖片的名稱至列表，並記錄總數)
no_output_files = []
for input_file in input_files:
    if input_file not in output_files:
        no_output_files.append(input_file)
print('沒有推理輸出的圖片數量: ', len(no_output_files))
# Out:
# 等待推理的圖片數量:  600
# 完成推理的圖片數量:  600
# 沒有推理輸出的圖片數量:  0
